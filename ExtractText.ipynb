# %%
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# DEFINE CONSTANTS
file_path_in = "/content/drive/My Drive/Roadmap_EN.xml"
file_path_out = "/content/drive/My Drive/Roadmap_Text_EN.csv"

# %%
from google.cloud import translate
import six
import sys

import os

# !pip install html2text
import html2text

# %%
f = open(file_path_in, "r")

from lxml import etree
tree = etree.parse(f)

list = ""

for node in tree.xpath('.//mxCell'):
  if 'value' in node.attrib:
    list = list +  html2text.html2text(node.attrib['value']) + ";"
    

xml = list
f = open(file_path_out, "w")
f.write(xml)
f.close()
